# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')

# %%
df
# Out:
#              date     home_team    away_team  home_score  away_score  \
# 0      1872-11-30      Scotland      England           0           0
# 1      1873-03-08       England     Scotland           4           2
# 2      1874-03-07      Scotland      England           2           1
# 3      1875-03-06       England     Scotland           2           2
# 4      1876-03-04      Scotland      England           3           0
# ...           ...           ...          ...         ...         ...
# 41535  2019-11-19    Kyrgyzstan   Tajikistan           1           1
# 41536  2019-11-19       Vietnam     Thailand           0           0
# 41537  2019-11-19      Malaysia    Indonesia           2           0
# 41538  2019-11-19  Turkmenistan    Sri Lanka           2           0
# 41539  2019-11-19       Lebanon  North Korea           0           0
#
#                          tournament          city       country  neutral
# ...

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
listx = list(df['tournament'].unique())

# %%
listx
# Out:
# ['Friendly',
#  'British Championship',
#  'Copa Lipton',
#  'Copa Newton',
#  'Copa Premio Honor Argentino',
#  'Copa Premio Honor Uruguayo',
#  'Copa Roca',
#  'Copa América',
#  'Copa Chevallier Boutell',
#  'Nordic Championship',
#  'International Cup',
#  'Baltic Cup',
#  'Balkan Cup',
#  'FIFA World Cup',
#  'Copa Rio Branco',
#  'FIFA World Cup qualification',
#  'CCCF Championship',
#  'NAFU Championship',
#  'Copa Oswaldo Cruz',
#  'Pan American Championship',
#  'Copa del Pacífico',
#  "Copa Bernardo O'Higgins",
#  'AFC Asian Cup qualification',
#  'Atlantic Cup',
#  'AFC Asian Cup',
#  'African Cup of Nations',
#  'Copa Paz del Chaco',
#  'Merdeka Tournament',
#  'UEFA Euro qualification',
#  'UEFA Euro',
#  'Windward Islands Tournament',
#  'African Cup of Nations qualification',
#  'Vietnam Independence Cup',
#  'Copa Carlos Dittborn',
#  'CONCACAF Championship',
#  'Copa Juan Pinto Durán',
#  'UAFA Cup',
#  'South Pacific Games',
# ...

# %%
dfa.tournament.value_counts()
# Out:
# Friendly                                17036
# FIFA World Cup qualification             7236
# UEFA Euro qualification                  2582
# African Cup of Nations qualification     1672
# FIFA World Cup                            900
#                                         ...
# World Unity Cup                             4
# OSN Cup                                     4
# AFF Championship qualification              2
# Atlantic Heritage Cup                       2
# Copa América qualification                  2
# Name: tournament, Length: 112, dtype: int64

# %%
dfa.shape
# Out:
# (41540, 10)

# %%
dfa.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_score', 'away_score',
#        'tournament', 'city', 'country', 'neutral', 'year'],
#       dtype='object')

# %%
nehru = dfa[dfa['tournament']=='Nehru Cup']

# %%
nehru
# Out:
#              date    home_team    away_team  home_score  away_score  \
# 12092  1982-02-16        India     China PR           1           1
# 12101  1982-02-18        India  South Korea           2           2
# 12110  1982-02-20  South Korea      Uruguay           2           2
# 12113  1982-02-22     China PR      Uruguay           0           0
# 12119  1982-02-25        India      Uruguay           1           3
# ...           ...          ...          ...         ...         ...
# 34313  2012-08-28        India        Nepal           0           0
# 34314  2012-08-29     Cameroon     Maldives           3           1
# 34315  2012-08-30        Syria        Nepal           2           0
# 34316  2012-08-31        India     Cameroon           0           1
# 34317  2012-09-02        India     Cameroon           2           2
#
#       tournament       city country  neutral  year
# 12092  Nehru Cup   Calcutta   India    False  1982
# ...

# %%
dicta = dfa.country.value_counts()
print("Country that hosted the highest number of matches is",dicta.keys()[0],'with',dicta[0],'matches hosted')
# Out:
# Country that hosted the highest number of matches is United States with 1154 matches hosted

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
fifa = df[df['tournament']=='FIFA World Cup']

# %%
dates = fifa.date.tolist()

# %%
yrs=[]
for date in dates:
    yr=date.split('-')[0]
    if yr not in yrs:
        yrs.append(yr)
dictOfCountries={}

# %%
for i in range(len(yrs)):
    for j in range(len(fifa[fifa['year']==eval(yrs[i])].country.unique())):
        if yrs[i] in dictOfCountries.keys():
            dictOfCountries[yrs[i]].append(fifa[fifa['year']==eval(yrs[i])].country.unique()[j])
        else:
            dictOfCountries[yrs[i]]=[fifa[fifa['year']==eval(yrs[i])].country.unique()[j]]

# %%
dictOfCountries
# Out:
# {'1930': ['Uruguay'],
#  '1934': ['Italy'],
#  '1938': ['France'],
#  '1950': ['Brazil'],
#  '1954': ['Switzerland'],
#  '1958': ['Sweden'],
#  '1962': ['Chile'],
#  '1966': ['England'],
#  '1970': ['Mexico'],
#  '1974': ['Germany'],
#  '1978': ['Argentina'],
#  '1982': ['Spain'],
#  '1986': ['Mexico'],
#  '1990': ['Italy'],
#  '1994': ['United States'],
#  '1998': ['France'],
#  '2002': ['South Korea', 'Japan'],
#  '2006': ['Germany'],
#  '2010': ['South Africa'],
#  '2014': ['Brazil'],
#  '2018': ['Russia']}
